# %%
import numpy as np
import scipy as sp
import pandas as pd
import os

# %matplotlib inline
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
ROOT_PATH = os.getcwd()
DATA_PATH = ROOT_PATH + '/datasets/data/'

# %%
from ldm import LDM
from datasets.load_data import load_sample_data

## Load the sample data
sample_data = load_sample_data()
## Training the distance
ldm = LDM()
# sample_data.diff_pairs
ldm.fit(sample_data.data, sample_data.sim_pairs, sample_data.diff_pairs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-f19d367bdc37> in <module>()
#       7 ldm = LDM()
#       8 # sample_data.diff_pairs
# ----> 9 ldm.fit(sample_data.data, sample_data.sim_pairs, sample_data.diff_pairs)
#
# /Users/beingzy/Documents/Projects/learning_dist_metrics/ldm.pyc in fit(self, X, S, D)
#      64         _ratio: float
#      65         """
# ---> 66         self._fit(X, S, D)
#      67         return self
#      68
#
# /Users/beingzy/Documents/Projects/learning_dist_metrics/ldm.pyc in _fit(self, X, S, D)
#     128
#     129         start_time = time.time()
# --> 130         fitted = minimize(objective_func, init, method="L-BFGS-B", bounds = bnds)
#     131         duration = time.time() - start_time
#     132
#
# ...

# %%
## Load the sample data
sample_data = load_sample_data()
## Training the distance
ldm = LDM()
# sample_data.diff_pairs
ldm.fit(sample_data.data, sample_data.sim_pairs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-db326a9de4ed> in <module>()
#       2 y      = sample_data.target
#       3
# ----> 4 trans_x = true_x * ldm.get_transform_matrix()
#       5 ## Load the sample data
#       6 sample_data = load_sample_data()
#
# ValueError: operands could not be broadcast together with shapes (100,3) (0,)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(true_x[:, 0], true_x[:, 1], true_x[:, 2], c = y)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(trans_x[:, 0], trans_x[:, 1], trans_x[:, 2], c = y)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
